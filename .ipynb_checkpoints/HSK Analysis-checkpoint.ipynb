# %%
import pandas as pd
import re
import time
import itertools
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
df = pd.read_csv('hsk_cleaned.csv')

# %%
df_hsk1 = df[df['Level'] == '1']
df_hsk2 = df[df['Level'] == '2']
df_hsk3 = df[df['Level'] == '3']
df_hsk4 = df[df['Level'] == '4']
df_hsk5 = df[df['Level'] == '5']
df_hsk6 = df[df['Level'] == '6']
df_hsk7_9 = df[df['Level'] == '7-9']

# %%
hsk1_hanzi_set = set(list(''.join([word for word in (df_hsk1['Simplified'] + df_hsk1['Traditional'])])))
hsk2_hanzi_set = set(list(''.join([word for word in (df_hsk2['Simplified'] + df_hsk2['Traditional'])])))
hsk3_hanzi_set = set(list(''.join([word for word in (df_hsk3['Simplified'] + df_hsk3['Traditional'])])))
hsk4_hanzi_set = set(list(''.join([word for word in (df_hsk4['Simplified'] + df_hsk4['Traditional'])])))
hsk5_hanzi_set = set(list(''.join([word for word in (df_hsk5['Simplified'] + df_hsk5['Traditional'])])))
hsk6_hanzi_set = set(list(''.join([word for word in (df_hsk6['Simplified'] + df_hsk6['Traditional'])])))
hsk7_9_hanzi_set = set(list(''.join([word for word in (df_hsk7_9['Simplified'] + df_hsk7_9['Traditional'])])))
hsk_hanzi_set = set(list(''.join([word for word in (df['Simplified'] + df['Traditional'])])))

# %%
hsk1_word_set = set(list(df_hsk1['Simplified']) + list(df_hsk1['Traditional']))
hsk2_word_set = set(list(df_hsk2['Simplified']) + list(df_hsk2['Traditional']))
hsk3_word_set = set(list(df_hsk3['Simplified']) + list(df_hsk3['Traditional']))
hsk4_word_set = set(list(df_hsk4['Simplified']) + list(df_hsk4['Traditional']))
hsk5_word_set = set(list(df_hsk5['Simplified']) + list(df_hsk5['Traditional']))
hsk6_word_set = set(list(df_hsk6['Simplified']) + list(df_hsk6['Traditional']))
hsk7_9_word_set = set(list(df_hsk7_9['Simplified']) + list(df_hsk7_9['Traditional']))
hsk_word_set = set(list(df['Simplified']) + list(df['Traditional']))

# %%
hsk6_word_set
# Out:
# {'场地',
#  '取款機',
#  '岗位',
#  '雨衣',
#  '官司',
#  '命',
#  '太陽能',
#  '戰場',
#  '本',
#  '踢',
#  '為何',
#  '用得著',
#  '機動車',
#  '轨道',
#  '打断',
#  '装备',
#  '边缘',
#  '節假日',
#  '构建',
#  '欺负',
#  '驚喜',
#  '設計師',
#  '灵活',
#  '好容易',
#  '聘请',
#  '合约',
#  '打發',
#  '過後',
#  '权',
#  '允許',
#  '歌星',
#  '往来',
#  '侵犯',
#  '入學',
#  '強盜',
#  '無邊',
#  '看好',
#  '前來',
#  '赖',
#  '消耗',
#  '防范',
#  '果樹',
#  '軍隊',
#  '两手',
#  '核心',
#  '一同',
#  '簡介',
#  '骄傲',
#  '领取',
#  '防範',
#  '侧',
#  '被告',
#  '早晚',
#  '之類',
#  '出名',
#  '次數',
#  '約定',
#  '稿子',
#  '塞',
#  '意願',
#  '觀光',
#  '惊人',
#  '肝',
#  '往后',
#  '昌盛',
#  '评选',
#  '長假',
#  '长短',
#  '平衡',
#  '自学',
#  '側',
#  '凉鞋',
#  '前方',
#  '電動',
#  '战略',
#  '暴力',
#  '权力',
#  '成品',
#  '娃娃',
#  '遺憾',
#  '优质',
#  '算是',
#  '正當',
#  '打官司',
#  '熱水器',
#  '症状',
#  '歲數',
#  '絕',
#  '漲',
#  '赛',
#  '很难说',
#  '駐',
#  '偏',
#  '写字台',
#  '暈',
#  '踏实',
#  '一時',
#  '赶上',
#  '指定',
#  '客车',
#  '宇航员',
#  '宫',
#  '成',
#  '招聘',
#  '這就是說',
#  '通话',
#  '背心',
#  '宗教',
#  '两侧',
#  '区分',
#  '指著',
#  '定价',
#  '暴雨',
#  '舞蹈',
#  '黨',
#  '波动',
#  '灭',
#  '铜牌',
#  '罪恶',
#  '長遠',
#  '白領',
#  '鉴定',
#  '必將',
#  '为何',
#  '档案',
#  '补习',
#  '持有',
#  '要麼',
#  '日语',
#  '司长',
#  '指头',
#  '公',
#  '宴會',
#  '傷口',
#  '好似',
#  '金钱',
#  '當成',
#  '拖鞋',
#  '过后',
#  '车展',
#  '往來',
#  '理财',
#  '不再',
#  '夺取',
#  '罢工',
#  '阴谋',
#  '跳水',
#  '最终',
#  '凶',
#  '用处',
#  '為此',
#  '节',
#  '畅通',
#  '战术',
#  '低温',
#  '酷',
#  '對抗',
#  '军舰',
#  '炸弹',
#  '线路',
#  '台灯',
#  '錄音機',
#  '机动车',
#  '往年',
#  '照耀',
#  '集',
#  '园地',
#  '发放',
#  '当成',
#  '慢车',
#  '排行榜',
#  '軍事',
#  '日夜',
#  '文娛',
#  '伤亡',
#  '净',
#  '哲学',
#  '氧气',
#  '创建',
#  '大师',
#  '虽',
#  '就是說',
#  '要素',
#  '自言自語',
#  '內衣',
#  '加盟',
#  '壺',
#  '電車',
#  '暢通',
#  '人权',
#  '特',
#  '没收',
#  '嘉賓',
#  '專用',
#  '上市',
#  '开头',
#  '復甦',
#  '伤口',
#  '精美',
#  '開關',
#  '路過',
#  '安检',
#  '打造',
#  '戶外',
#  '出访',
#  '壮观',
#  '路过',
#  '暴风雨',
#  '百分点',
#  '球星',
#  '波浪',
#  '不便',
#  '捐赠',
#  '创意',
#  '打发',
#  '近視',
#  '新興',
#  '融合',
#  '说明书',
#  '會見',
#  '師生',
#  '兴旺',
#  '因',
#  '忽略',
#  '礦',
#  '高層',
#  '剧',
#  '联赛',
#  '聯賽',
#  '公主',
#  '端午节',
#  '诞生',
#  '名額',
#  '賺',
#  '覺',
#  '夺',
#  '醋',
#  '此前',
#  '百分點',
#  '棉',
#  '家園',
#  '悬',
#  '牺牲',
#  '大批',
#  '革新',
#  '跪',
#  '刚好',
#  '街頭',
#  '發炎',
#  '康復',
#  '循環',
#  '一齊',
#  '好轉',
#  '素質',
#  '盼望',
#  '城镇',
#  '種種',
#  '試點',
#  '梅花',
#  '恰當',
#  '负',
#  '賭博',
#  '只顾',
#  '自學',
#  '飛船',
#  '橫',
#  '清洁工',
#  '糾紛',
#  '出场',
#  '重組',
#  '望见',
#  '巩固',
#  '戰術',
#  '極端',
#  '残酷',
#  '扑',
#  '打動',
#  '不通',
#  '渠道',
#  '名勝',
#  '開設',
#  '法庭',
#  '精品',
#  '整顿',
#  '彎曲',
#  '海底',
#  '養老',
#  '壶',
#  '能否',
#  '線路',
#  '节奏',
#  '踏',
#  '缘故',
#  '走私',
#  '混',
#  '再說',
#  '撤离',
#  '车牌',
#  '主持人',
#  '宠物',
#  '提升',
#  '学会',
#  '内地',
#  '炸彈',
#  '球员',
#  '田径',
#  '金額',
#  '挨',
#  '本質',
#  '岁数',
#  '所',
#  '要不然',
#  '意想不到',
#  '首腦',
#  '奉獻',
#  '高檔',
#  '賬',
#  '井',
#  '大街',
#  '原',
#  '車牌',
#  '潜力',
#  '老鄉',
#  '懸',
#  '聊',
#  '修车',
#  '族',
#  '處長',
#  '猛',
#  '圓珠筆',
#  '野生',
#  '增進',
#  '聖誕節',
#  '動畫',
#  '親屬',
#  '此次',
#  '低溫',
#  '妙',
#  '適當',
#  '出台',
#  '認同',
#  '心臟',
#  '丧失',
#  '隐藏',
#  '牽',
#  '民歌',
#  '变形',
#  '出入',
#  '回应',
#  '足',
#  '依次',
#  '如',
#  '算了',
#  '與',
#  '缺陷',
#  '爽',
#  '止',
#  '海軍',
#  '试点',
#  '打印機',
#  '場館',
#  '事後',
#  '水泥',
#  '果醬',
#  '照樣',
#  '撤銷',
#  '直升機',
#  '上台',
#  '借鉴',
#  '杰出',
#  '磨',
#  '冷气',
#  '隐私',
#  '师父',
#  '檔案',
#  '测定',
#  '乌云',
#  '雙打',
#  '罪惡',
#  '直升机',
#  '军事',
#  '修車',
#  '大賽',
#  '特大',
#  '于|於',
#  '本身',
#  '心愿',
#  '爆',
#  '貧困',
#  '軌道',
#  '国会',
#  '病房',
#  '近视',
#  '道教',
#  '疼痛',
#  '市民',
#  '陰影',
#  '土',
#  '通話',
#  '感人',
#  '處處',
#  '大使',
#  '恰恰',
#  '背着',
#  '轉',
#  '哇',
#  '公鸡',
#  '犯罪',
#  '治病',
#  '長短',
#  '時裝',
#  '绘画',
#  '长远',
#  '养老',
#  '峰会',
#  '車展',
#  '收取',
#  '依赖',
#  '民警',
#  '墓',
#  '趕不上',
#  '看得見',
#  '上當',
#  '作战',
#  '出訪',
#  '舌頭',
#  '师生',
#  '章',
#  '裝備',
#  '仿佛',
#  '不料',
#  '谦虚',
#  '操纵',
#  '求职',
#  '识字',
#  '天然',
#  '精',
#  '悲慘',
#  '次数',
#  '劇',
#  '广阔',
#  '選舉',
#  '薪水',
#  '傳出',
#  '時時',
#  '再说',
#  '緣故',
#  '姑姑',
#  '花費',
#  '录像',
#  '傳言',
#  '道歉',
#  '清洁',
#  '宇航員',
#  '出行',
#  '優質',
#  '领袖',
#  '對外',
#  '發起',
#  '扭',
#  '救命',
#  '有关',
#  '尖',
#  '通报',
#  '欺負',
#  '總經理',
#  '盡',
#  '重组',
#  '時節',
#  '指着',
#  '待會兒',
#  '心願',
#  '当天',
#  '强势',
#  '名义',
#  '全新',
#  '用得着',
#  '宮',
#  '曉得',
#  '定位',
#  '参展',
#  '先锋',
#  '藏',
#  '母',
#  '惨',
#  '往後',
#  '揭',
#  '綠化',
#  '增进',
#  '窗口',
#  '內地',
#  '金融',
#  '節奏',
#  '陸軍',
#  '頑皮',
#  '单打',
#  '鋪',
#  '品牌',
#  '大米',
#  '掏',
#  '頑強',
#  '犯規',
#  '撿',
#  '尽',
#  '乳制品',
#  '患者',
#  '鞏固',
#  '因素',
#  '佔據',
#  '国产',
#  '处处',
#  '死亡',
#  '不僅僅',
#  '陆军',
#  '部隊',
#  '傷亡',
#  '烏雲',
#  '弯曲',
#  '平凡',
#  '发电',
#  '崗位',
#  '一模一样',
#  '剑',
#  '富人',
#  '挨打',
#  '股东',
#  '首席',
#  '難忘',
#  '捕',
#  '外出',
#  '祝愿',
#  '幻想',
#  '远离',
#  '盲人',
#  '同行',
#  '游玩',
#  '总经理',
#  '看',
#  '纠纷',
#  '傷員',
#  '歌词',
#  '傾向',
#  '心靈',
#  '遗憾',
#  '墨水',
#  '毒品',
#  '种种',
#  '小于',
#  '不见',
#  '混合',
#  '活跃',
#  '办事处',
#  '膜',
#  '產量',
#  '孤独',
#  '樂曲',
#  '外头',
#  '關愛',
#  '運作',
#  '设计师',
#  '残疾人',
#  '藥品',
#  '补助',
#  '英雄',
#  '支撑',
#  '中外',
#  '借鑒',
#  '錄像',
#  '联盟',
#  '楼道',
#  '常規',
#  '另',
#  '親眼',
#  '住宅',
#  '壓迫',
#  '消滅',
#  '海灣',
#  '順',
#  '兒科',
#  '反响',
#  '挨着',
#  '炸',
#  '好學',
#  '寫字檯',
#  '多媒體',
#  '飞行员',
#  '认同',
#  '珠寶',
#  '佛教',
#  '發怒',
#  '三明治',
#  '转动',
#  '迎来',
#  '首脑',
#  '電器',
#  '海洋',
#  '图书',
#  '法语',
#  '卧铺',
#  '啦',
#  '空军',
#  '評',
#  '賽場',
#  '踏實',
#  '筆試',
#  '笑声',
#  '腫',
#  '形',
#  '粥',
#  '解说',
#  '不怎麼樣',
#  '协会',
#  '平方米',
#  '指頭',
#  '採納',
#  '重建',
#  '辦事處',
#  '島',
#  '从没',
#  '罷了',
#  '据',
#  '聘請',
#  '乐曲',
#  '券',
#  '祖父',
#  '海军',
#  '補助',
#  '收養',
#  '平台',
#  '素质',
#  '长久',
#  '茄子',
#  '咨詢',
#  '定时',
#  '栏目',
#  '戰略',
#  '科研',
#  '送行',
#  '搭配',
#  '慢車',
#  '钟头',
#  '檯燈',
#  '洗衣粉',
#  '必将',
#  '高手',
#  '搭',
#  '新兴',
#  '车号',
#  '信仰',
#  '再生',
#  '陪同',
#  '此处',
#  '高科技',
#  '袖珍',
#  '實踐',
#  '強壯',
#  '争夺',
#  '潛力',
#  '传媒',
#  '遠離',
#  '康复',
#  '藍天',
#  '節能',
#  '关联',
#  '军队',
#  '出動',
#  '超',
#  '創建',
#  '作戰',
#  '研发',
#  '强壮',
#  '危机',
#  '热水',
#  '節',
#  '同一',
#  '當作',
#  '支援',
#  '好学',
#  '顯出',
#  '文娱',
#  '情绪',
#  '防守',
#  '暴露',
#  '办学',
#  '化解',
#  '起點',
#  '觉',
#  '會長',
#  '同期',
#  '奪取',
#  '赌博',
#  '只顧',
#  '强盗',
#  '馒头',
#  '消灭',
#  '闊',
#  '明日',
#  '互動',
#  '电动',
#  '外頭',
#  '轉動',
#  '食慾',
#  '便',
#  '無效',
#  '电力',
#  '决策',
#  '少儿',
#  '长',
#  '企图',
#  '食欲',
#  '沿着',
#  '嫌',
#  '滴',
#  '信用',
#  '发病',
#  '转',
#  '求職',
#  '壯觀',
#  '咨询',
#  '清明节',
#  '职责',
#  '小於',
#  '热水器',
#  '長跑',
#  '考場',
#  '机械',
#  '拐',
#  '長久',
#  '機關',
#  '毁',
#  '考场',
#  '遊戲機',
#  '冲',
#  '司長',
#  '税',
#  '跨',
#  '长跑',
#  '吊',
#  '政黨',
#  '賴',
#  '进攻',
#  '原諒',
#  '自来水',
#  '白领',
#  '父子',
#  '人權',
#  '镇',
#  '老乡',
#  '压迫',
#  '國會',
#  '选拔',
#  '炒股',
#  '辦學',
#  '行程',
#  '亲属',
#  '省錢',
#  '強勢',
#  '房价',
#  '和諧',
#  '珠宝',
#  '總監',
#  '稅',
#  '外来',
#  '面對面',
#  '铅笔',
#  '果酱',
#  '景點',
#  '酱油',
#  '扎|紮',
#  '地板',
#  '外來',
#  '講課',
#  '让座',
#  '挖',
#  '暈車',
#  '场馆',
#  '城区',
#  '應急',
#  '開通',
#  '障礙',
#  '升學',
#  '衡量',
#  '愤怒',
#  '淨',
#  '悲惨',
#  '聯手',
#  '宏大',
#  '通讯',
#  '關聯',
#  '調研',
#  '送禮',
#  '管道',
#  '橋梁',
#  '病情',
#  '入',
#  '服',
#  '監測',
#  '聽取',
#  '残疾',
#  '飛行員',
#  '捐',
#  '利',
#  '債',
#  '研發',
#  '流感',
#  '内衣',
#  '打牌',
#  '只得',
#  '船長',
#  '仪器',
#  '干涉',
#  '之类',
#  '从不',
#  '泥',
#  '开创',
#  '場景',
#  '異常',
#  '出臺',
#  '识',
#  '外币',
#  '主流',
#  '圖書',
#  '變形',
#  '厂商',
#  '端午節',
#  '寫字樓',
#  '威胁',
#  '古典',
#  '涉及',
#  '驚人',
#  '传输',
#  '考題',
#  '國歌',
#  '派出',
#  '通道',
#  '与',
#  '煮',
#  '细胞',
#  '船员',
#  '名胜',
#  '拖',
#  '時期',
#  '太阳能',
#  '主角',
#  '口試',
#  '局',
#  '操縱',
#  '料',
#  '气氛',
#  '知名',
#  '雜',
#  '驻',
#  '审查',
#  '崇拜',
#  '投票',
#  '户外',
#  '誕生',
#  '惊喜',
#  '显出',
#  '海报',
#  '捐款',
#  '上当',
#  '影星',
#  '活躍',
#  '追究',
#  '花费',
#  '旋转',
#  '炸药',
#  '民工',
#  '响声',
#  '識字',
#  '清潔',
#  '富有',
#  '策略',
#  '时期',
#  '救助',
#  '欄目',
#  '过渡',
#  '写字楼',
#  '药品',
#  '名義',
#  '理',
#  '高层',
#  '解',
#  '外资',
#  '殘酷',
#  '补课',
#  '公雞',
#  '面嚮',
#  '分工',
#  '保健',
#  '蓝领',
#  '外衣',
#  '塔',
#  '酱',
#  '歌詞',
#  '织',
#  '光輝',
#  '上帝',
#  '圣诞节',
#  '捐助',
#  '开夜车',
#  '臥鋪',
#  '一贯',
#  '敢於',
#  '趕忙',
#  '場地',
#  '四處',
#  '看得见',
#  '报刊',
#  '简介',
#  '電力',
#  '威脅',
#  '都市',
#  '外部',
#  '捉',
#  '網頁',
#  '儿科',
#  '拆遷',
#  '吉祥',
#  '婦女',
#  '民主',
#  '好转',
#  '傍晚',
#  '祖國',
#  '发起',
#  '这就是说',
#  '田',
#  '衝',
#  '廣闊',
#  '熱點',
#  '宽阔',
#  '强化',
#  '战场',
#  '抱歉',
#  '招',
#  '聯盟',
#  '一模一樣',
#  '报考',
#  '高考',
#  '理財',
#  '中華',
#  '前来',
#  '城區',
#  '犯规',
#  '无效',
#  '歌唱',
#  '寬闊',
#  '醬',
#  '檔',
#  '样',
#  '涼鞋',
#  '峰會',
#  '时装',
#  '无关',
#  '發放',
#  '牵',
#  '開頭',
#  '報考',
#  '反響',
#  '副',
#  '用心',
#  '金额',
#  '盜版',
#  '音像',
#  '循环',
#  '無關',
#  '党',
#  '生活费',
#  '天下',
#  '录音机',
#  '运作',
#  '參賽',
#  '开设',
#  '出动',
#  '娛樂',
#  '踩',
#  '卻是',
#  '医药',
#  '公众',
#  '險',
#  '炒作',
#  '鎮',
#  '諸位',
#  '有事',
#  '讓座',
#  '变更',
#  '大道',
#  '风暴',
#  '工商',
#  '矿',
#  '自言自语',
#  '擔憂',
#  '座谈会',
#  '金錢',
#  '假日',
#  '客車',
#  '戰友',
#  '疾病',
#  '一齐',
#  ...}

# %%
# for a given hanzi, return the lowest level that it appears in
def get_hanzi_level(hanzi):
    if hanzi in hsk1_hanzi_set:
        return '1'
    if hanzi in hsk2_hanzi_set:
        return '2'
    if hanzi in hsk3_hanzi_set:
        return '3'
    if hanzi in hsk4_hanzi_set:
        return '4'
    if hanzi in hsk5_hanzi_set:
        return '5'
    if hanzi in hsk6_hanzi_set:
        return '6'
    if hanzi in hsk7_9_hanzi_set:
        return '7-9'
    return 'Unknown'

# %%
# Create a dictionary of characters where each character

# %%
get_word_difficulty_time = 0

# %%
import pandas as pd
import re
import itertools

df = pd.read_csv('hsk_cleaned.csv')

df_hsk1 = df[df['Level'] == '1']
df_hsk2 = df[df['Level'] == '2']
df_hsk3 = df[df['Level'] == '3']
df_hsk4 = df[df['Level'] == '4']
df_hsk5 = df[df['Level'] == '5']
df_hsk6 = df[df['Level'] == '6']
df_hsk7_9 = df[df['Level'] == '7-9']

hsk1_hanzi_set = set(list(''.join([word for word in (df_hsk1['Simplified'] + df_hsk1['Traditional'])])))
hsk2_hanzi_set = set(list(''.join([word for word in (df_hsk2['Simplified'] + df_hsk2['Traditional'])])))
hsk3_hanzi_set = set(list(''.join([word for word in (df_hsk3['Simplified'] + df_hsk3['Traditional'])])))
hsk4_hanzi_set = set(list(''.join([word for word in (df_hsk4['Simplified'] + df_hsk4['Traditional'])])))
hsk5_hanzi_set = set(list(''.join([word for word in (df_hsk5['Simplified'] + df_hsk5['Traditional'])])))
hsk6_hanzi_set = set(list(''.join([word for word in (df_hsk6['Simplified'] + df_hsk6['Traditional'])])))
hsk7_9_hanzi_set = set(list(''.join([word for word in (df_hsk7_9['Simplified'] + df_hsk7_9['Traditional'])])))
hsk_hanzi_set = set(list(''.join([word for word in (df['Simplified'] + df['Traditional'])])))

hsk1_word_set = set(list(df_hsk1['Simplified']) + list(df_hsk1['Traditional']))
hsk2_word_set = set(list(df_hsk2['Simplified']) + list(df_hsk2['Traditional']))
hsk3_word_set = set(list(df_hsk3['Simplified']) + list(df_hsk3['Traditional']))
hsk4_word_set = set(list(df_hsk4['Simplified']) + list(df_hsk4['Traditional']))
hsk5_word_set = set(list(df_hsk5['Simplified']) + list(df_hsk5['Traditional']))
hsk6_word_set = set(list(df_hsk6['Simplified']) + list(df_hsk6['Traditional']))
hsk7_9_word_set = set(list(df_hsk7_9['Simplified']) + list(df_hsk7_9['Traditional']))
hsk_word_set = set(list(df['Simplified']) + list(df['Traditional']))

# for a given hanzi, return the lowest level that it appears in
def get_hanzi_level(hanzi):
    if hanzi in hsk1_hanzi_set:
        return '1'
    if hanzi in hsk2_hanzi_set:
        return '2'
    if hanzi in hsk3_hanzi_set:
        return '3'
    if hanzi in hsk4_hanzi_set:
        return '4'
    if hanzi in hsk5_hanzi_set:
        return '5'
    if hanzi in hsk6_hanzi_set:
        return '6'
    if hanzi in hsk7_9_hanzi_set:
        return '7-9'
    return 'Unknown'


def is_hanzi(char):
    # hanzi are between U+4E00 and U+9FFF
    return ord(char) <= 40959 and ord(char) >= 19968


def is_all_hanzi(string):
    return all([is_hanzi(char) for char in list(string)])

# this function was written by ChatGPT
def escape_regex(string):
    regex_reserved_chars = r'\^$.|?*+(){}[]'
    escaped_string = re.sub(f'([{re.escape(regex_reserved_chars)}])', r'\\\1', string)
    return escaped_string


# split text into chunks of Hanzi split by non-Hanzi characters
def split_into_hanzi_chunks(text):
    if is_all_hanzi(text):
        return [text]
    
    chunks = []
    
    if not isinstance(text, str):
        return []
    
    non_hanzi_characters = []
    
    for char in list(text):
        if not is_hanzi(char):
            non_hanzi_characters.append(escape_regex(char))
    
    regex_split_string = '|'.join(list(set(non_hanzi_characters)))
    split_string = re.split(regex_split_string, text)
    
    for string in split_string:
        if len(string) > 0:
            chunks.append(string)
            
    return chunks


# reverse of the function above
def split_into_non_hanzi_chunks(text):
    chunks = []
    
    if not isinstance(text, str):
        return []
    
    curr_chunk = ''
    
    for char in list(text):
        if not is_hanzi(char):
            curr_chunk += char
        if is_hanzi(char) and curr_chunk != '':
            chunks.append(curr_chunk)
            curr_chunk = ''
            
    return chunks

    
def get_word_difficulty(word):
    if len(word) == 1:
        return get_hanzi_level(word)
    if word in hsk1_word_set:
        return '1'
    elif word in hsk2_word_set:
        return '2'
    elif word in hsk3_word_set:
        return '3'
    elif word in hsk4_word_set:
        return '4'
    elif word in hsk5_word_set:
        return '5'
    elif word in hsk6_word_set:
        return '6'
    elif word in hsk7_9_word_set:
        return '7-9'
    return 'Unknown'


def word_in_hsk(word):
    return word in hsk_word_set or word in hsk_hanzi_set
    
# '法庭将于明年开庭审理他们涉嫌为中国从事间谍活动的案子'
# sliding window parsing algorithm
def tokenize_hanzi_string(hanzi_text):
    tokens = []
    text_length = len(hanzi_text)
    curr_index = 1
    
    while hanzi_text != '':
        curr_word = hanzi_text[:curr_index]
        if not word_in_hsk(curr_word):
            if curr_index > 1:
                new_word = hanzi_text[:curr_index - 1]
                hanzi_text = hanzi_text[curr_index - 1:]
            else:
                new_word = hanzi_text[:curr_index]
                hanzi_text = hanzi_text[curr_index:]
            new_word_level = get_word_difficulty(new_word)
            new_token = [new_word, new_word_level]
            tokens.append(new_token)
            curr_index = 1
        else:
            # if this is the last word to parse
            if curr_word == hanzi_text:
                new_word = hanzi_text[:curr_index]
                hanzi_text = ''
                new_word_level = get_word_difficulty(new_word)
                new_token = [new_word, new_word_level]
                tokens.append(new_token)
            curr_index += 1
            
    return tokens


def parse_text(text):
    tokens = []
    hanzi_chunks = split_into_hanzi_chunks(text)
    non_hanzi_chunks = split_into_non_hanzi_chunks(text)
    
    if len(hanzi_chunks) == 0:
        chunks = non_hanzi_chunks
    elif len(non_hanzi_chunks) == 0:
        chunks = hanzi_chunks
    # interweave the two chunks depending on which type of chunk (hanzi or non-hanzi)
    # appears in the text
    elif is_hanzi(text[0]):
        chunks = [chunk for chunk in itertools.chain(*itertools.zip_longest(hanzi_chunks, non_hanzi_chunks)) if chunk is not None]
    else:
        chunks = [chunk for chunk in itertools.chain(*itertools.zip_longest(non_hanzi_chunks, hanzi_chunks)) if chunk is not None]
    
    for chunk in chunks:
        # is this a hanzi chunk? If so, get tokens for it and append them to overall token list
        if is_hanzi(chunk[0]):
            chunk_tokens = tokenize_hanzi_string(chunk)
            tokens.extend(chunk_tokens)
        else:
            non_hanzi_token = [chunk, 'Not Hanzi']
            tokens.append(non_hanzi_token)
            
    return tokens

# %%
text = """
两名英国人周五（5月10日）被告知，法庭将于明年开庭审理他们涉嫌为中国从事间谍活动的案子。其中一人名叫克里斯托弗·卡什（Christopher Cash）29岁，曾经是英国国会的一名研究人员，另一名是克里斯托弗·贝里 (Christopher Berry)，32岁，曾是牛津大学学者。

伦敦警方上个月指控他们违反《官方保密法》，非法向中国提供有损国家安全或利益的信息。警方说，他们“获取、收集、记录、公布或向任何其他人传播”对敌国有用的“物品、笔记、文件或信息”。

卡什和贝里尚未提出抗辩，两人周五在伦敦老贝利法院出席了简短的听证会，向法庭确认了自己的姓名和出生日期。

路透社说，法庭告诉他们，法庭将在明年春季或者夏季开庭审理他们的案子，两人已经获准保释，直到今年10月4日的听证会。

英国《每日邮报》指出，“不同寻常的是，他们（两名被告）没有被要求进入被告席，而是被允许坐在律师旁边的法律席上。”

贝里是牛津的一名学者。英国警方上个月发表的声明说，贝里被指控在2021年12月28日至2023年2月3日期间，搜集和传递对敌国有用的“物品、笔记、文件或信息”。

警方也以同样的罪名指控了卡什，但是其违法的时间线在2022年1月20日至2023年2月3日期间。卡什曾经是保守党保安事务国务大臣图根达特（Tom Tugendhat，又译董勤达）创立的“中国研究小组”（China Research Group）的总监，并且得到了国会职员证件。

英国警方指控卡什和贝里不仅保持相互联系，还与一名被认为是中国情报人员的人有联系。他们通过英国一家帮助学生和老师在中国找工作的公司得到了在中国教学的工作，两人成为了朋友。

每日邮报说，卡什和贝里在2018年左右都在杭州东方中学当过老师。

《星期日泰晤士报》指，保安官员认为他在中国工作时被招揽，回到英国后渗透对北京有用的政治网络。卡什通过律师在其后发表的声明中说：“我至今的工作都是尝试教育其他人认识中国共产党带来的挑战及威胁。针对我的夸张报道指控我做的事是有违我所有理念的。”

最近欧洲多个国家都发生了有关中国间谍活动的案子，引起了人们广泛的担忧。北京对此一概否认。中国大使馆发言人称这些指控是“恶意诽谤”，并强调中国从未参与过任何形式的间谍活动。“我们坚决反对这种无端指控，敦促英国停止反华政治操弄，”该发言人说。

英国在这个问题上表达了非常坚定的立场。英国首相苏纳克上个月在华沙讲话的时候表示，有着中国官方背景的黑客针对英国议会的网络系统进行了“恶意的网络袭击”。

本周稍早，苏纳克表示，“这些‘恶意的角色’可能侵入了英国军队的支付系统。”英国媒体表示，有理由相信这次网络攻击的幕后是中国的黑客。
"""

# %%
t1 = time.time()

for i in range(100):
    tokens = parse_text(text)

t2 = time.time()
    
print('Took an average of {} seconds for 100 tries'.format((t2 - t1) / 100))
# Took an average of 1.3367192149162292 seconds for 100 tries
# Took an average of 0.0016269207000732422 seconds for 100 tries
# Out:
# Took an average of 0.0009500861167907714 seconds for 100 tries

# %%
parse_text(text)
# Out:
# [{'\n': 'Not Hanzi'},
#  {'两': '1'},
#  {'名': '1'},
#  {'英': '2'},
#  {'国': '1'},
#  {'人': '1'},
#  {'周': '2'},
#  {'五': '1'},
#  {'（5': 'Not Hanzi'},
#  {'月': '1'},
#  {'10': 'Not Hanzi'},
#  {'日': '1'},
#  {'）': 'Not Hanzi'},
#  {'被告': '6'},
#  {'知': '1'},
#  {'，': 'Not Hanzi'},
#  {'法庭': '6'},
#  {'将': '3'},
#  {'于': '2'},
#  {'明年': '1'},
#  {'开': '1'},
#  {'庭': '2'},
#  {'审': '6'},
#  {'理': '2'},
#  {'他们': '1'},
#  {'涉嫌': '7-9'},
#  {'为': '2'},
#  {'中国': '1'},
#  {'从事': '3'},
#  {'间谍': '7-9'},
#  {'活动': '2'},
#  {'的': '1'},
#  {'案': '4'},
#  {'子': '1'},
#  {'。': 'Not Hanzi'},
#  {'其中': '2'},
#  {'一': '1'},
#  {'人': '1'},
#  {'名': '1'},
#  {'叫': '1'},
#  {'克': '2'},
#  {'里': '1'},
#  {'斯': '7-9'},
#  {'托': '5'},
#  {'弗': 'Unknown'},
#  {'·': 'Not Hanzi'},
#  {'卡': '2'},
#  {'什': '1'},
#  {'（Christopher Cash）29': 'Not Hanzi'},
#  {'岁': '1'},
#  {'，': 'Not Hanzi'},
#  {'曾经': '3'},
#  {'是': '1'},
#  {'英': '2'},
#  {'国': '1'},
#  {'国会': '6'},
#  {'的': '1'},
#  {'一': '1'},
#  {'名': '1'},
#  {'研究': '4'},
#  {'人员': '3'},
#  {'，': 'Not Hanzi'},
#  {'另': '3'},
#  {'一': '1'},
#  {'名': '1'},
#  {'是': '1'},
#  {'克': '2'},
#  {'里': '1'},
#  {'斯': '7-9'},
#  {'托': '5'},
#  {'弗': 'Unknown'},
#  {'·': 'Not Hanzi'},
#  {'贝': '4'},
#  {'里': '1'},
#  {' (Christopher Berry)，32': 'Not Hanzi'},
#  {'岁': '1'},
#  {'，': 'Not Hanzi'},
#  {'曾': '3'},
#  {'是': '1'},
#  {'牛': '1'},
#  {'津': '7-9'},
#  {'大学': '1'},
#  {'学者': '5'},
#  {'。\n\n': 'Not Hanzi'},
#  {'伦': '7-9'},
#  {'敦': '7-9'},
#  {'警': '3'},
#  {'方': '1'},
#  {'上': '1'},
#  {'个': '1'},
#  {'月': '1'},
#  {'指': '3'},
#  {'控': '5'},
#  {'他们': '1'},
#  {'违反': '5'},
#  {'《': 'Not Hanzi'},
#  {'官方': '4'},
#  {'保密': '4'},
#  {'法': '2'},
#  {'》，': 'Not Hanzi'},
#  {'非法': '7-9'},
#  {'向': '2'},
#  {'中国': '1'},
#  {'提供': '4'},
#  {'有': '1'},
#  {'损': '5'},
#  {'国家': '1'},
#  {'安全': '2'},
#  {'或': '2'},
#  {'利益': '4'},
#  {'的': '1'},
#  {'信息': '2'},
#  {'。': 'Not Hanzi'},
#  {'警': '3'},
#  {'方': '1'},
#  {'说': '1'},
#  {'，': 'Not Hanzi'},
#  {'他们': '1'},
#  {'“': 'Not Hanzi'},
#  {'获取': '4'},
#  {'、': 'Not Hanzi'},
#  {'收集': '5'},
#  {'、': 'Not Hanzi'},
#  {'记录': '3'},
#  {'、': 'Not Hanzi'},
#  {'公布': '3'},
#  {'或': '2'},
#  {'向': '2'},
#  {'任何': '3'},
#  {'其他': '2'},
#  {'人': '1'},
#  {'传播': '3'},
#  {'”': 'Not Hanzi'},
#  {'对': '1'},
#  {'敌': '4'},
#  {'国有': '7-9'},
#  {'用': '1'},
#  {'的': '1'},
#  {'“': 'Not Hanzi'},
#  {'物品': '6'},
#  {'、': 'Not Hanzi'},
#  {'笔记': '2'},
#  {'、': 'Not Hanzi'},
#  {'文件': '3'},
#  {'或': '2'},
#  {'信息': '2'},
#  {'”。\n\n': 'Not Hanzi'},
#  {'卡': '2'},
#  {'什': '1'},
#  {'和': '1'},
#  {'贝': '4'},
#  {'里': '1'},
#  {'尚未': '7-9'},
#  {'提出': '2'},
#  {'抗': '6'},
#  {'辩': '4'},
#  {'，': 'Not Hanzi'},
#  {'两': '1'},
#  {'人': '1'},
#  {'周': '2'},
#  {'五': '1'},
#  {'在': '1'},
#  {'伦': '7-9'},
#  {'敦': '7-9'},
#  {'老': '1'},
#  {'贝': '4'},
#  {'利': '2'},
#  {'法院': '4'},
#  {'出席': '4'},
#  {'了': '1'},
#  {'简短': '7-9'},
#  {'的': '1'},
#  {'听': '1'},
#  {'证': '3'},
#  {'会': '1'},
#  {'，': 'Not Hanzi'},
#  {'向': '2'},
#  {'法庭': '6'},
#  {'确认': '4'},
#  {'了': '1'},
#  {'自己': '2'},
#  {'的': '1'},
#  {'姓名': '2'},
#  {'和': '1'},
#  {'出生': '2'},
#  {'日期': '1'},
#  {'。\n\n': 'Not Hanzi'},
#  {'路': '1'},
#  {'透': '4'},
#  {'社': '3'},
#  {'说': '1'},
#  {'，': 'Not Hanzi'},
#  {'法庭': '6'},
#  {'告诉': '1'},
#  {'他们': '1'},
#  {'，': 'Not Hanzi'},
#  {'法庭': '6'},
#  {'将': '3'},
#  {'在': '1'},
#  {'明年': '1'},
#  {'春季': '4'},
#  {'或者': '2'},
#  {'夏季': '4'},
#  {'开': '1'},
#  {'庭': '2'},
#  {'审': '6'},
#  {'理': '2'},
#  {'他们': '1'},
#  {'的': '1'},
#  {'案': '4'},
#  {'子': '1'},
#  {'，': 'Not Hanzi'},
#  {'两': '1'},
#  {'人': '1'},
#  {'已经': '2'},
#  {'获': '4'},
#  {'准': '1'},
#  {'保': '3'},
#  {'释': '4'},
#  {'，': 'Not Hanzi'},
#  {'直到': '3'},
#  {'今年': '1'},
#  {'10': 'Not Hanzi'},
#  {'月': '1'},
#  {'4': 'Not Hanzi'},
#  {'日': '1'},
#  {'的': '1'},
#  {'听': '1'},
#  {'证': '3'},
#  {'会': '1'},
#  {'。\n\n': 'Not Hanzi'},
#  {'英': '2'},
#  {'国': '1'},
#  {'《': 'Not Hanzi'},
#  {'每': '3'},
#  {'日': '1'},
#  {'邮': '3'},
#  {'报': '2'},
#  {'》': 'Not Hanzi'},
#  {'指出': '3'},
#  {'，“': 'Not Hanzi'},
#  {'不同': '2'},
#  {'寻常': '7-9'},
#  {'的': '1'},
#  {'是': '1'},
#  {'，': 'Not Hanzi'},
#  {'他们': '1'},
#  {'（': 'Not Hanzi'},
#  {'两': '1'},
#  {'名': '1'},
#  {'被告': '6'},
#  {'）': 'Not Hanzi'},
#  {'没有': '1'},
#  {'被': '3'},
#  {'要求': '2'},
#  {'进入': '2'},
#  {'被告': '6'},
#  {'席': '4'},
#  {'，': 'Not Hanzi'},
#  {'而是': '4'},
#  {'被': '3'},
#  {'允许': '6'},
#  {'坐': '1'},
#  {'在': '1'},
#  {'律师': '4'},
#  {'旁边': '1'},
#  {'的': '1'},
#  {'法律': '4'},
#  {'席': '4'},
#  {'上': '1'},
#  {'。”\n\n': 'Not Hanzi'},
#  {'贝': '4'},
#  {'里': '1'},
#  {'是': '1'},
#  {'牛': '1'},
#  {'津': '7-9'},
#  {'的': '1'},
#  {'一': '1'},
#  {'名': '1'},
#  {'学者': '5'},
#  {'。': 'Not Hanzi'},
#  {'英': '2'},
#  {'国': '1'},
#  {'警': '3'},
#  {'方': '1'},
#  {'上': '1'},
#  {'个': '1'},
#  {'月': '1'},
#  {'发表': '3'},
#  {'的': '1'},
#  {'声明': '3'},
#  {'说': '1'},
#  {'，': 'Not Hanzi'},
#  {'贝': '4'},
#  {'里': '1'},
#  {'被': '3'},
#  {'指': '3'},
#  {'控': '5'},
#  {'在': '1'},
#  {'2021': 'Not Hanzi'},
#  {'年': '1'},
#  {'12': 'Not Hanzi'},
#  {'月': '1'},
#  {'28': 'Not Hanzi'},
#  {'日': '1'},
#  {'至': '3'},
#  {'2023': 'Not Hanzi'},
#  {'年': '1'},
#  {'2': 'Not Hanzi'},
#  {'月': '1'},
#  {'3': 'Not Hanzi'},
#  {'日期': '1'},
#  {'间': '1'},
#  {'，': 'Not Hanzi'},
#  {'搜集': '7-9'},
#  {'和': '1'},
#  {'传递': '5'},
#  {'对': '1'},
#  {'敌': '4'},
#  {'国有': '7-9'},
#  {'用': '1'},
#  {'的': '1'},
#  {'“': 'Not Hanzi'},
#  {'物品': '6'},
#  {'、': 'Not Hanzi'},
#  {'笔记': '2'},
#  {'、': 'Not Hanzi'},
#  {'文件': '3'},
#  {'或': '2'},
#  {'信息': '2'},
#  {'”。\n\n': 'Not Hanzi'},
#  {'警': '3'},
#  {'方': '1'},
#  {'也': '1'},
#  {'以': '2'},
#  {'同样': '2'},
#  {'的': '1'},
#  {'罪': '6'},
#  {'名': '1'},
#  {'指': '3'},
#  {'控': '5'},
#  {'了': '1'},
#  {'卡': '2'},
#  {'什': '1'},
#  {'，': 'Not Hanzi'},
#  {'但是': '2'},
#  {'其': '2'},
#  {'违法': '5'},
#  {'的': '1'},
#  {'时间': '1'},
#  {'线': '3'},
#  {'在': '1'},
#  {'2022': 'Not Hanzi'},
#  {'年': '1'},
#  {'1': 'Not Hanzi'},
#  {'月': '1'},
#  {'20': 'Not Hanzi'},
#  {'日': '1'},
#  {'至': '3'},
#  {'2023': 'Not Hanzi'},
#  {'年': '1'},
#  {'2': 'Not Hanzi'},
#  {'月': '1'},
#  {'3': 'Not Hanzi'},
#  {'日期': '1'},
#  {'间': '1'},
#  {'。': 'Not Hanzi'},
#  {'卡': '2'},
#  {'什': '1'},
#  {'曾经': '3'},
#  {'是': '1'},
#  {'保守': '4'},
#  {'党': '6'},
#  {'保安': '3'},
#  {'事务': '7-9'},
#  {'国': '1'},
#  {'务': '2'},
#  {'大臣': '7-9'},
#  {'图': '1'},
#  {'根': '3'},
#  {'达': '3'},
#  {'特': '2'},
#  {'（Tom Tugendhat，': 'Not Hanzi'},
#  {'又': '2'},
#  {'译': '4'},
#  {'董': '7-9'},
#  {'勤': '5'},
#  {'达': '3'},
#  {'）': 'Not Hanzi'},
#  {'创立': '5'},
#  {'的': '1'},
#  {'“': 'Not Hanzi'},
#  {'中国': '1'},
#  {'研究': '4'},
#  {'小组': '2'},
#  {'”（China Research Group）': 'Not Hanzi'},
#  {'的': '1'},
#  {'总监': '6'},
#  {'，': 'Not Hanzi'},
#  {'并且': '3'},
#  {'得到': '1'},
#  {'了': '1'},
#  {'国会': '6'},
#  {'职员': '7-9'},
#  {'证件': '3'},
#  {'。\n\n': 'Not Hanzi'},
#  {'英': '2'},
#  {'国': '1'},
#  {'警': '3'},
#  {'方': '1'},
#  {'指': '3'},
#  {'控': '5'},
#  {'卡': '2'},
#  {'什': '1'},
#  {'和': '1'},
#  {'贝': '4'},
#  {'里': '1'},
#  {'不仅': '3'},
#  {'保持': '3'},
#  {'相互': '3'},
#  {'联系': '3'},
#  {'，': 'Not Hanzi'},
#  {'还': '1'},
#  {'与': '4'},
#  {'一': '1'},
#  {'名': '1'},
#  {'被': '3'},
#  {'认为': '2'},
#  {'是': '1'},
#  {'中国': '1'},
#  {'情报': '7-9'},
#  {'人员': '3'},
#  {'的': '1'},
#  {'人': '1'},
#  {'有': '1'},
#  {'联系': '3'},
#  {'。': 'Not Hanzi'},
#  {'他们': '1'},
#  {'通过': '2'},
#  {'英': '2'},
#  {'国': '1'},
#  {'一': '1'},
#  {'家': '1'},
#  {'帮助': '2'},
#  {'学生': '1'},
#  {'和': '1'},
#  {'老师': '1'},
#  {'在': '1'},
#  {'中国': '1'},
#  {'找': '1'},
#  {'工作': '1'},
#  {'的': '1'},
#  {'公司': '2'},
#  {'得到': '1'},
#  {'了': '1'},
#  {'在': '1'},
#  {'中国': '1'},
#  {'教学': '2'},
#  {'的': '1'},
#  {'工作': '1'},
#  {'，': 'Not Hanzi'},
#  {'两': '1'},
#  {'人': '1'},
#  {'成为': '2'},
#  {'了': '1'},
#  {'朋友': '1'},
#  {'。\n\n': 'Not Hanzi'},
#  {'每': '3'},
#  {'日': '1'},
#  {'邮': '3'},
#  {'报': '2'},
#  {'说': '1'},
#  {'，': 'Not Hanzi'},
#  {'卡': '2'},
#  {'什': '1'},
#  {'和': '1'},
#  {'贝': '4'},
#  {'里': '1'},
#  {'在': '1'},
#  {'2018': 'Not Hanzi'},
#  {'年': '1'},
#  {'左右': '3'},
#  {'都': '1'},
#  {'在': '1'},
#  {'杭': 'Unknown'},
#  {'州': 'Unknown'},
#  {'东方': '2'},
#  {'中学': '1'},
#  {'当': '2'},
#  {'过': '1'},
#  {'老师': '1'},
#  {'。\n\n《': 'Not Hanzi'},
#  {'星期日': '1'},
#  {'泰': '7-9'},
#  {'晤': '7-9'},
#  {'士': '4'},
#  {'报': '2'},
#  {'》': 'Not Hanzi'},
#  {'指': '3'},
#  {'，': 'Not Hanzi'},
#  {'保安': '3'},
#  {'官员': '7-9'},
#  {'认为': '2'},
#  {'他': '1'},
#  {'在': '1'},
#  {'中国': '1'},
#  {'工作': '1'},
#  {'时': '1'},
#  {'被': '3'},
#  {'招揽': '7-9'},
#  {'，': 'Not Hanzi'},
#  {'回到': '1'},
#  {'英': '2'},
#  {'国': '1'},
#  {'后': '1'},
#  {'渗透': '7-9'},
#  {'对': '1'},
#  {'北京': '1'},
#  {'有用': '1'},
#  {'的': '1'},
#  {'政治': '4'},
#  {'网络': '4'},
#  {'。': 'Not Hanzi'},
#  {'卡': '2'},
#  {'什': '1'},
#  {'通过': '2'},
#  {'律师': '4'},
#  {'在': '1'},
#  {'其后': '7-9'},
#  {'发表': '3'},
#  {'的': '1'},
#  {'声明': '3'},
#  {'中': '1'},
#  {'说': '1'},
#  {'：“': 'Not Hanzi'},
#  {'我': '1'},
#  {'至今': '3'},
#  {'的': '1'},
#  {'工作': '1'},
#  {'都': '1'},
#  {'是': '1'},
#  {'尝试': '5'},
#  {'教育': '2'},
#  {'其他': '2'},
#  {'人': '1'},
#  {'认识': '1'},
#  {'中国': '1'},
#  {'共': '2'},
#  {'产': '3'},
#  {'党': '6'},
#  {'带来': '2'},
#  {'的': '1'},
#  {'挑战': '4'},
#  {'及': '3'},
#  {'威胁': '6'},
#  {'。': 'Not Hanzi'},
#  {'针对': '4'},
#  {'我': '1'},
#  {'的': '1'},
#  {'夸张': '7-9'},
#  {'报道': '3'},
#  {'指': '3'},
#  {'控': '5'},
#  {'我': '1'},
#  {'做': '1'},
#  {'的': '1'},
#  {'事': '1'},
#  {'是': '1'},
#  {'有': '1'},
#  {'违': '5'},
#  {'我': '1'},
#  {'所有': '2'},
#  {'理念': '7-9'},
#  {'的': '1'},
#  {'。”\n\n': 'Not Hanzi'},
#  {'最近': '2'},
#  {'欧': 'Unknown'},
#  {'洲': 'Unknown'},
#  {'多': '1'},
#  {'个': '1'},
#  {'国家': '1'},
#  {'都': '1'},
#  {'发生': '3'},
#  {'了': '1'},
#  {'有关': '6'},
#  {'中国': '1'},
#  {'间谍': '7-9'},
#  {'活动': '2'},
#  {'的': '1'},
#  {'案': '4'},
#  {'子': '1'},
#  {'，': 'Not Hanzi'},
#  {'引起': '4'},
#  {'了': '1'},
#  {'人们': '2'},
#  {'广泛': '5'},
#  {'的': '1'},
#  {'担忧': '6'},
#  {'。': 'Not Hanzi'},
#  {'北京': '1'},
#  {'对': '1'},
#  {'此': '3'},
#  {'一概': '7-9'},
#  {'否认': '3'},
#  {'。': 'Not Hanzi'},
#  {'中国': '1'},
#  {'大使馆': '3'},
#  {'发言人': '6'},
#  {'称': '2'},
#  {'这些': '1'},
#  {'指': '3'},
#  {'控': '5'},
#  {'是': '1'},
#  {'“': 'Not Hanzi'},
#  {'恶意': '7-9'},
#  {'诽谤': '7-9'},
#  {'”，': 'Not Hanzi'},
#  {'并': '3'},
#  {'强调': '3'},
#  {'中国': '1'},
#  {'从未': '7-9'},
#  {'参与': '4'},
#  {'过': '1'},
#  {'任何': '3'},
#  {'形式': '3'},
#  {'的': '1'},
#  {'间谍': '7-9'},
#  {'活动': '2'},
#  {'。“': 'Not Hanzi'},
#  {'我们': '1'},
#  {'坚决': '3'},
#  {'反对': '3'},
#  {'这': '1'},
#  {'种': '3'},
#  {'无': '4'},
#  {'端': '6'},
#  {'指': '3'},
#  {'控': '5'},
#  {'，': 'Not Hanzi'},
#  {'敦促': '7-9'},
#  {'英': '2'},
#  {'国': '1'},
#  {'停止': '3'},
#  {'反': '3'},
#  {'华': '3'},
#  {'政治': '4'},
#  {'操': '4'},
#  {'弄': '2'},
#  {'，”': 'Not Hanzi'},
#  {'该': '2'},
#  {'发言人': '6'},
#  {'说': '1'},
#  {'。\n\n': 'Not Hanzi'},
#  {'英': '2'},
#  {'国': '1'},
#  {'在': '1'},
#  {'这': '1'},
#  {'个': '1'},
#  {'问题': '2'},
#  {'上': '1'},
#  {'表达': '3'},
#  {'了': '1'},
#  {'非常': '1'},
#  {'坚定': '5'},
#  {'的': '1'},
#  {'立场': '5'},
#  {'。': 'Not Hanzi'},
#  {'英': '2'},
#  {'国': '1'},
#  {'首相': '6'},
#  {'苏': '6'},
#  {'纳': '6'},
#  {'克': '2'},
#  {'上': '1'},
#  {'个': '1'},
#  {'月': '1'},
#  {'在': '1'},
#  {'华': '3'},
#  {'沙': '3'},
#  {'讲话': '2'},
#  {'的': '1'},
#  {'时候': '1'},
#  {'表示': '2'},
#  {'，': 'Not Hanzi'},
#  {'有着': '5'},
#  {'中国': '1'},
#  {'官方': '4'},
#  {'背景': '4'},
#  {'的': '1'},
#  {'黑客': '7-9'},
#  {'针对': '4'},
#  {'英': '2'},
#  {'国': '1'},
#  {'议会': '7-9'},
#  {'的': '1'},
#  {'网络': '4'},
#  {'系统': '4'},
#  {'进行': '2'},
#  {'了': '1'},
#  {'“': 'Not Hanzi'},
#  {'恶意': '7-9'},
#  {'的': '1'},
#  {'网络': '4'},
#  {'袭击': '7-9'},
#  {'”。\n\n': 'Not Hanzi'},
#  {'本': '1'},
#  {'周': '2'},
#  {'稍': '5'},
#  {'早': '1'},
#  {'，': 'Not Hanzi'},
#  {'苏': '6'},
#  {'纳': '6'},
#  {'克': '2'},
#  {'表示': '2'},
#  {'，“': 'Not Hanzi'},
#  {'这些': '1'},
#  {'‘': 'Not Hanzi'},
#  {'恶意': '7-9'},
#  {'的': '1'},
#  {'角色': '4'},
#  {'’': 'Not Hanzi'},
#  {'可能': '2'},
#  {'侵': '6'},
#  {'入': '2'},
#  {'了': '1'},
#  {'英': '2'},
#  {'国': '1'},
#  {'军队': '6'},
#  {'的': '1'},
#  {'支付': '3'},
#  {'系统': '4'},
#  {'。”': 'Not Hanzi'},
#  {'英': '2'},
#  {'国': '1'},
#  {'媒体': '3'},
#  {'表示': '2'},
#  {'，': 'Not Hanzi'},
#  {'有': '1'},
#  {'理由': '3'},
#  {'相信': '2'},
#  {'这': '1'},
#  {'次': '1'},
#  {'网络': '4'},
#  {'攻击': '6'},
#  {'的': '1'},
#  {'幕后': '7-9'},
#  {'是': '1'},
#  {'中国': '1'},
#  {'的': '1'},
#  {'黑客': '7-9'}]

# %%
tokenize_hanzi_string('中文名字')
# Out:
# word 中文名 not found
# [{'中文': '1'}, {'名字': '1'}]

# %%
df[df['Simplified'].str.contains('名字')]
# Out:
#     Simplified Traditional  Pinyin Level
# 235         名字          名字  míngzi     1

# %%
x = parse_text('这些文字全部都是中文')
print(x)
# Out:
# ['这些文字全部都是中文']
# 1
# [{'这些': '1'}, {'文字': '3'}, {'全部': '2'}, {'都': '1'}, {'是': '1'}, {'中文': '1'}]

# %%
x
# Out:
# [{'这': '1'},
#  {'些': '1'},
#  {'文': '1'},
#  {'字': '1'},
#  {'全': '2'},
#  {'部': '2'},
#  {'都': '1'},
#  {'是': '1'},
#  {'中': '1'},
#  {'文': '1'}]

# %%
hanzi_chunks = split_into_hanzi_chunks('这些文字全部都是中文')

# %%
type(hanzi_chunks)
# Out:
# list
